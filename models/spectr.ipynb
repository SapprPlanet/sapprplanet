# %%
# Import libraries
import pyshtools
import numpy as np
import matplotlib.pyplot as plt

# %%
# use pyshtools to load clm coefficients
# 'clm_Br_Maven_Plus.txt' - Maven data  75S <= latitude <= 75N + MGS in other
# points + in missing nodes
clm_comb = pyshtools.SHCoeffs.from_file('clm_Br_Maven_Plus.txt')

# %%
clm_comb.plot_spectrum(lmax=134)
# Out:
# c:\Users\batov\.conda\envs\pygmt\Lib\site-packages\pyshtools\shclasses\shcoeffs.py:2486: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot: xlabel='Spherical harmonic degree', ylabel='Power'>)
